# %%
# !pip install transformers==2.4.1
# Out:
# Collecting transformers==2.4.1
#   Using cached https://files.pythonhosted.org/packages/ee/fc/bd726a15ab2c66dc09306689d04da07a3770dad724f0883f0a4bfb745087/transformers-2.4.1-py3-none-any.whl
# Collecting numpy (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/6d/ad/ff3b21ebfe79a4d25b4a4f8e5cf9fd44a204adb6b33c09010f566f51027a/numpy-1.21.6-cp37-cp37m-manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Collecting sentencepiece (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/d8/87/b37ebc960d0a85e10785a1a92d796edbd975840bee150a9ae3ba5d7a0250/sentencepiece-0.1.99.tar.gz
# Collecting sacremoses (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/28/78/fef8d089db5b97546fd6d1ff2e813b8544e85670bf3a8c378c9d0250b98d/sacremoses-0.0.53.tar.gz
# Collecting filelock (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/00/45/ec3407adf6f6b5bf867a4462b2b0af27597a26bd3cd6e2534cb6ab029938/filelock-3.12.2-py3-none-any.whl
# Collecting tokenizers==0.0.11 (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/5f/cb/3e8902d528538972873d0e9e4e47a31d1849a98e057009e9d383637c96fb/tokenizers-0.0.11-cp37-cp37m-manylinux1_x86_64.whl
# Collecting requests (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/70/8e/0e2d847013cb52cd35b38c009bb167a1a26b2ce6cd6965bf26b47bc0bf44/requests-2.31.0-py3-none-any.whl
# Collecting regex!=2019.12.17 (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/d4/db/c9f52597c7f3c0538ddc0ded7efb6e629555745e6f8e362404b82ee8e398/regex-2023.8.8-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_12_x86_64.manylinux2010_x86_64.whl
# Collecting tqdm>=4.27 (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/00/e5/f12a80907d0884e6dff9c16d0c0114d81b8cd07dc3ae54c5e962cc83037e/tqdm-4.66.1-py3-none-any.whl
# Collecting boto3 (from transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/84/85/e895e6ca369f406432c5f5f186b107f1e1a6a2408b60a081de32021fd818/boto3-1.28.49-py3-none-any.whl
# Requirement already satisfied: six in /snap/jupyter/6/lib/python3.7/site-packages (from sacremoses->transformers==2.4.1) (1.12.0)
# Collecting click (from sacremoses->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/00/2e/d53fa4befbf2cfa713304affc7ca780ce4fc1fd8710527771b58311a3229/click-8.1.7-py3-none-any.whl (97kB)
#      |████████████████████████████████| 102kB 3.3MB/s ta 0:00:01
# Collecting joblib (from sacremoses->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/10/40/d551139c85db202f1f384ba8bcf96aca2f329440a844f924c8a0040b6d02/joblib-1.3.2-py3-none-any.whl (302kB)
#      |████████████████████████████████| 307kB 16.0MB/s eta 0:00:01
# Collecting charset-normalizer<4,>=2 (from requests->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/bf/a0/188f223c7d8b924fb9b554b9d27e0e7506fd5bf9cfb6dbacb2dfd5832b53/charset_normalizer-3.2.0-py3-none-any.whl (46kB)
#      |████████████████████████████████| 51kB 22.4MB/s eta 0:00:01
# Collecting urllib3<3,>=1.21.1 (from requests->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/9b/81/62fd61001fa4b9d0df6e31d47ff49cfa9de4af03adecf339c7bc30656b37/urllib3-2.0.4-py3-none-any.whl (123kB)
#      |████████████████████████████████| 133kB 51.5MB/s eta 0:00:01
# Requirement already satisfied: certifi>=2017.4.17 in /snap/jupyter/6/lib/python3.7/site-packages (from requests->transformers==2.4.1) (2019.3.9)
# Collecting idna<4,>=2.5 (from requests->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/fc/34/3030de6f1370931b9dbb4dad48f6ab1015ab1d32447850b9fc94e60097be/idna-3.4-py3-none-any.whl (61kB)
#      |████████████████████████████████| 71kB 27.8MB/s eta 0:00:01
# Collecting s3transfer<0.7.0,>=0.6.0 (from boto3->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/d9/17/a3b666f5ef9543cfd3c661d39d1e193abb9649d0cfbbfee3cf3b51d5af02/s3transfer-0.6.2-py3-none-any.whl (79kB)
#      |████████████████████████████████| 81kB 29.6MB/s eta 0:00:01
# Collecting botocore<1.32.0,>=1.31.49 (from boto3->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/1e/13/efec7af5071e9a385a85deb3b31edd290374df7e24177cdf42ce00130b54/botocore-1.31.49-py3-none-any.whl (11.2MB)
#      |████████████████████████████████| 11.2MB 50.3MB/s eta 0:00:01
# Collecting jmespath<2.0.0,>=0.7.1 (from boto3->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/31/b4/b9b800c45527aadd64d5b442f9b932b00648617eb5d63d2c7a6587b7cafc/jmespath-1.0.1-py3-none-any.whl
# Collecting importlib-metadata; python_version < "3.8" (from click->sacremoses->transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/ff/94/64287b38c7de4c90683630338cf28f129decbba0a44f0c6db35a873c73c4/importlib_metadata-6.7.0-py3-none-any.whl
# Requirement already satisfied: python-dateutil<3.0.0,>=2.1 in /snap/jupyter/6/lib/python3.7/site-packages (from botocore<1.32.0,>=1.31.49->boto3->transformers==2.4.1) (2.8.0)
# Collecting zipp>=0.5 (from importlib-metadata; python_version < "3.8"->click->sacremoses->transformers==2.4.1)
#   Downloading https://files.pythonhosted.org/packages/5b/fa/c9e82bbe1af6266adf08afb563905eb87cab83fde00a0a08963510621047/zipp-3.15.0-py3-none-any.whl
# Collecting typing-extensions>=3.6.4; python_version < "3.8" (from importlib-metadata; python_version < "3.8"->click->sacremoses->transformers==2.4.1)
#   Using cached https://files.pythonhosted.org/packages/ec/6b/63cc3df74987c36fe26157ee12e09e8f9db4de771e0f3404263117e75b95/typing_extensions-4.7.1-py3-none-any.whl
# Building wheels for collected packages: sentencepiece, sacremoses
#   Building wheel for sentencepiece (setup.py) ... error
#   ERROR: Complete output from command /snap/jupyter/6/bin/python -u -c 'import setuptools, tokenize;__file__='"'"'/tmp/pip-install-8r8sob62/sentencepiece/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' bdist_wheel -d /tmp/pip-wheel-pz410nx_ --python-tag cp37:
#   ERROR: running bdist_wheel
#   running build
#   running build_py
#   creating build
#   creating build/lib.linux-x86_64-3.7
#   creating build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/__init__.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/_version.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/sentencepiece_model_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   copying src/sentencepiece/sentencepiece_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#   running build_ext
#   /bin/sh: 1: pkg-config: not found
#   ./build_bundled.sh: 21: ./build_bundled.sh: cmake: not found
#   ./build_bundled.sh: 22: ./build_bundled.sh: nproc: Permission denied
#   ./build_bundled.sh: 22: ./build_bundled.sh: cmake: not found
#   Traceback (most recent call last):
#     File "<string>", line 1, in <module>
#     File "/tmp/pip-install-8r8sob62/sentencepiece/setup.py", line 198, in <module>
#       test_suite='sentencepiece_test.suite',
#     File "/snap/jupyter/6/lib/python3.7/site-packages/setuptools/__init__.py", line 145, in setup
#       return distutils.core.setup(**attrs)
#     File "/snap/jupyter/6/lib/python3.7/distutils/core.py", line 148, in setup
#       dist.run_commands()
#     File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 966, in run_commands
#       self.run_command(cmd)
#     File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/snap/jupyter/6/lib/python3.7/site-packages/wheel/bdist_wheel.py", line 192, in run
#       self.run_command('build')
#     File "/snap/jupyter/6/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/snap/jupyter/6/lib/python3.7/distutils/command/build.py", line 135, in run
#       self.run_command(cmd_name)
#     File "/snap/jupyter/6/lib/python3.7/distutils/cmd.py", line 313, in run_command
#       self.distribution.run_command(command)
#     File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 985, in run_command
#       cmd_obj.run()
#     File "/snap/jupyter/6/lib/python3.7/site-packages/setuptools/command/build_ext.py", line 78, in run
#       _build_ext.run(self)
#     File "/snap/jupyter/6/lib/python3.7/distutils/command/build_ext.py", line 340, in run
#       self.build_extensions()
#     File "/snap/jupyter/6/lib/python3.7/distutils/command/build_ext.py", line 449, in build_extensions
#       self._build_extensions_serial()
#     File "/snap/jupyter/6/lib/python3.7/distutils/command/build_ext.py", line 474, in _build_extensions_serial
#       self.build_extension(ext)
#     File "/tmp/pip-install-8r8sob62/sentencepiece/setup.py", line 87, in build_extension
#       subprocess.check_call(['./build_bundled.sh', __version__])
#     File "/snap/jupyter/6/lib/python3.7/subprocess.py", line 347, in check_call
#       raise CalledProcessError(retcode, cmd)
#   subprocess.CalledProcessError: Command '['./build_bundled.sh', '0.1.99']' returned non-zero exit status 127.
#   ----------------------------------------
#   ERROR: Failed building wheel for sentencepiece
#   Running setup.py clean for sentencepiece
#   Building wheel for sacremoses (setup.py) ... done
#   Stored in directory: /home/dlobo/snap/jupyter/6/.cache/pip/wheels/56/d5/b2/bc878b2bbddfbcc8fd62ca73c4fd842bd28c1fd3dbdf424c74
# Successfully built sacremoses
# Failed to build sentencepiece
# ERROR: botocore 1.31.49 has requirement urllib3<1.27,>=1.25.4, but you'll have urllib3 2.0.4 which is incompatible.
# Installing collected packages: numpy, sentencepiece, regex, zipp, typing-extensions, importlib-metadata, click, joblib, tqdm, sacremoses, filelock, tokenizers, charset-normalizer, urllib3, idna, requests, jmespath, botocore, s3transfer, boto3, transformers
#   Running setup.py install for sentencepiece ... error
#     ERROR: Complete output from command /snap/jupyter/6/bin/python -u -c 'import setuptools, tokenize;__file__='"'"'/tmp/pip-install-8r8sob62/sentencepiece/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-fw4ysnv0/install-record.txt --single-version-externally-managed --compile --user --prefix=:
#     ERROR: running install
#     running build
#     running build_py
#     creating build
#     creating build/lib.linux-x86_64-3.7
#     creating build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/__init__.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/_version.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/sentencepiece_model_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     copying src/sentencepiece/sentencepiece_pb2.py -> build/lib.linux-x86_64-3.7/sentencepiece
#     running build_ext
#     /bin/sh: 1: pkg-config: not found
#     ./build_bundled.sh: 21: ./build_bundled.sh: cmake: not found
#     ./build_bundled.sh: 22: ./build_bundled.sh: nproc: Permission denied
#     ./build_bundled.sh: 22: ./build_bundled.sh: cmake: not found
#     Traceback (most recent call last):
#       File "<string>", line 1, in <module>
#       File "/tmp/pip-install-8r8sob62/sentencepiece/setup.py", line 198, in <module>
#         test_suite='sentencepiece_test.suite',
#       File "/snap/jupyter/6/lib/python3.7/site-packages/setuptools/__init__.py", line 145, in setup
#         return distutils.core.setup(**attrs)
#       File "/snap/jupyter/6/lib/python3.7/distutils/core.py", line 148, in setup
#         dist.run_commands()
#       File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 966, in run_commands
#         self.run_command(cmd)
#       File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/snap/jupyter/6/lib/python3.7/site-packages/setuptools/command/install.py", line 61, in run
#         return orig.install.run(self)
#       File "/snap/jupyter/6/lib/python3.7/distutils/command/install.py", line 545, in run
#         self.run_command('build')
#       File "/snap/jupyter/6/lib/python3.7/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/snap/jupyter/6/lib/python3.7/distutils/command/build.py", line 135, in run
#         self.run_command(cmd_name)
#       File "/snap/jupyter/6/lib/python3.7/distutils/cmd.py", line 313, in run_command
#         self.distribution.run_command(command)
#       File "/snap/jupyter/6/lib/python3.7/distutils/dist.py", line 985, in run_command
#         cmd_obj.run()
#       File "/snap/jupyter/6/lib/python3.7/site-packages/setuptools/command/build_ext.py", line 78, in run
#         _build_ext.run(self)
#       File "/snap/jupyter/6/lib/python3.7/distutils/command/build_ext.py", line 340, in run
#         self.build_extensions()
#       File "/snap/jupyter/6/lib/python3.7/distutils/command/build_ext.py", line 449, in build_extensions
#         self._build_extensions_serial()
#       File "/snap/jupyter/6/lib/python3.7/distutils/command/build_ext.py", line 474, in _build_extensions_serial
#         self.build_extension(ext)
#       File "/tmp/pip-install-8r8sob62/sentencepiece/setup.py", line 87, in build_extension
#         subprocess.check_call(['./build_bundled.sh', __version__])
#       File "/snap/jupyter/6/lib/python3.7/subprocess.py", line 347, in check_call
#         raise CalledProcessError(retcode, cmd)
#     subprocess.CalledProcessError: Command '['./build_bundled.sh', '0.1.99']' returned non-zero exit status 127.
#     ----------------------------------------
# ERROR: Command "/snap/jupyter/6/bin/python -u -c 'import setuptools, tokenize;__file__='"'"'/tmp/pip-install-8r8sob62/sentencepiece/setup.py'"'"';f=getattr(tokenize, '"'"'open'"'"', open)(__file__);code=f.read().replace('"'"'\r\n'"'"', '"'"'\n'"'"');f.close();exec(compile(code, __file__, '"'"'exec'"'"'))' install --record /tmp/pip-record-fw4ysnv0/install-record.txt --single-version-externally-managed --compile --user --prefix=" failed with error code 1 in /tmp/pip-install-8r8sob62/sentencepiece/

# %%
text = "Berlin ist nicht nur Weltmetropole und die Hauptstadt Deutschlands, sondern auch meine Heimatstadt. Jeden Morgen auf dem Weg zur Arbeit komme ich an vielen berühmten Sehenswürdigkeiten vorbei. Da ist zunächst der Große Tiergarten, welcher schon über 500 Jahre alt ist. Von hier ist es nicht weit bis zum Brandenburger Tor und der Siegessäule. Hier steige ich in die U-Bahn und fahre einige Stationen bis zum Alexanderplatz, wo sich die Weltzeituhr und das Wahrzeichen der Stadt, der Fernsehturm befinden. Von dort sind es nur wenige Minuten Fußweg bis zum Kurfürstendamm, der riesigen Einkaufsstraße mit zahlreichen Restaurants, Geschäften und Hotels. Hier arbeite ich als Hotelfachfrau und betreue die zahlreichen Gäste des Hotels, welche als Touristen Berlin besichtigen. Als echte Berlinerin kann ich ihnen dabei gute Tipps geben, welche Sehenswürdigkeiten sich wirklich lohnen und wie sie auf dem besten Wege dorthin gelangen. Sehr oft kommt man so mit den Gästen unserer Stadt ins Gespräch und erfährt, aus welchen Ländern sie angereist sind und ob es Ihnen in Berlin gefällt. Als besonderen Service bietet unser Hotel auch eigene Stadtrundfahrten an, die immer sehr gern gebucht werden."

# %%
from transformers import AutoTokenizer
from transformers import AutoModelForSeq2SeqLM

tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large")
inputs = tokenizer(text, return_tensors="pt").input_ids
model = AutoModelForSeq2SeqLM.from_pretrained("facebook/bart-large")
outputs = model.generate(inputs, max_new_tokens=256, do_sample=False)
tokenizer.decode(outputs[0], skip_special_tokens=True)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-3-70c545ad2d11> in <module>
# ----> 1 from transformers import AutoTokenizer
#       2 from transformers import AutoModelForSeq2SeqLM
#       3
#       4 tokenizer = AutoTokenizer.from_pretrained("facebook/bart-large")
#       5 inputs = tokenizer(text, return_tensors="pt").input_ids
#
# ModuleNotFoundError: No module named 'transformers'
